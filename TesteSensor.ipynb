# %% [markdown]
# <a href="https://colab.research.google.com/github/ManoelEric1212/Sesnorvibration/blob/main/TesteSensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataReconstruction = pd.read_csv('serial4.csv',sep=';')
dataReconstruction.head()
# Out:
#    acx   acy  acy.1
# 0  102  1023     84
# 1  102  1023     84
# 2  102  1023     84
# 3  102  1023     84
# 4  102  1023     84

# %%
dataReconstruction.columns
# Out:
# Index(['acx', 'acy', 'acy.1'], dtype='object')

# %%
dataReconstruction.rename(columns={'acy.1': 'acy'})
# Out:
#     acx   acy  acy
# 0   102  1023   84
# 1   102  1023   84
# 2   102  1023   84
# 3   102  1023   84
# 4   102  1023   84
# 5   102  1023   84
# 6   147  1023   84
# 7   147  1023   84
# 8   147  1023  121
# 9   147  1023  147
# 10  147  1023  147
# 11  147  1023  147
# 12  147  1023  147
# 13  147  1023  110
# 14  147  1023   92
# 15  137  1023   92
# 16  102  1023   92
# 17  102  1023   92
# 18  102  1023   92
# 19  102  1023   92
# 20  102  1023   92
# 21  102  1023   92
# 22  164  1023   92
# 23  137  1023   92
# 24  102  1023   92
# 25  102  1023   47
# 26  102  1023  129
# 27  102  1023  129

# %%
dataReconstruction.plot()

# %%
dataReconstruction.describe()
# Out:
#               acx     acy       acy.1
# count   28.000000    28.0   28.000000
# mean   121.178571  1023.0  100.285714
# std     22.949306     0.0   24.808686
# min    102.000000  1023.0   47.000000
# 25%    102.000000  1023.0   84.000000
# 50%    102.000000  1023.0   92.000000
# 75%    147.000000  1023.0  112.750000
# max    164.000000  1023.0  147.000000
